# %% [markdown]
# # **Memory Test on Drugged Islanders**
# # Context
#
# An experiment on the effects of anti-anxiety medicine on memory recall when being primed with happy or sad memories. The participants were done on novel Islanders whom mimic real-life humans in response to external factors.
#
# Drugs of interest (known-as) [Dosage 1, 2, 3]:
#
# A - Alprazolam (Xanax, Long-term) [1mg/3mg/5mg]
#
# T - Triazolam (Halcion, Short-term) [0.25mg/0.5mg/0.75mg]
#
# S- Sugar Tablet (Placebo) [1 tab/2tabs/3tabs]
#
# *Dosages follow a 1:1 ratio to ensure validity
# *Happy or Sad memories were primed 10 minutes prior to testing
# *Participants tested every day for 1 week to mimic addiction
#
# Content
#
# File contains information on participants drug treatment information along with their test scores.

# %%
import pandas as pd
import seaborn as sns
import seaborn as sb
import plotly.express as px
import numpy as np
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from palettable.colorbrewer.qualitative import Pastel1_7

# %%
df = pd.read_csv('Islander_data.csv')

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'age', 'Happy_Sad_group', 'Dosage', 'Drug',
#        'Mem_Score_Before', 'Mem_Score_After', 'Diff'],
#       dtype='object')

# %%
df.head()
# Out:
#   first_name last_name  age Happy_Sad_group  Dosage Drug  Mem_Score_Before  \
# 0    Bastian  Carrasco   25               H       1    A              63.5
# 1       Evan  Carrasco   52               S       1    A              41.6
# 2  Florencia  Carrasco   29               H       1    A              59.7
# 3      Holly  Carrasco   50               S       1    A              51.7
# 4     Justin  Carrasco   52               H       1    A              47.0
#
#    Mem_Score_After  Diff               name
# 0             61.2  -2.3    BastianCarrasco
# 1             40.7  -0.9       EvanCarrasco
# 2             55.1  -4.6  FlorenciaCarrasco
# 3             51.2  -0.5      HollyCarrasco
# 4             47.1   0.1     JustinCarrasco

# %%
df["name"] = df["first_name"] + df["last_name"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   first_name        198 non-null    object
#  1   last_name         198 non-null    object
#  2   age               198 non-null    int64
#  3   Happy_Sad_group   198 non-null    object
#  4   Dosage            198 non-null    int64
#  5   Drug              198 non-null    object
#  6   Mem_Score_Before  198 non-null    float64
#  7   Mem_Score_After   198 non-null    float64
#  8   Diff              198 non-null    float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 14.0+ KB

# %%
df.describe()
# Out:
#               age      Dosage  Mem_Score_Before  Mem_Score_After        Diff
# count  198.000000  198.000000        198.000000       198.000000  198.000000
# mean    39.530303    1.989899         57.967677        60.922222    2.954545
# std     12.023099    0.818504         15.766007        18.133851   10.754603
# min     24.000000    1.000000         27.200000        27.100000  -40.400000
# 25%     30.000000    1.000000         46.525000        47.175000   -3.175000
# 50%     37.000000    2.000000         54.800000        56.750000    1.700000
# 75%     48.000000    3.000000         68.400000        73.250000    5.925000
# max     83.000000    3.000000        110.000000       120.000000   49.000000

# %% [markdown]
# Exploratory Data Analysis

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(20, 10))
sb.countplot(x='Dosage', data=df, palette="Blues")
plt.title('Dosage', fontsize = 20)
plt.xticks(rotation = 90)
plt.xlabel('Dosage')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(20, 10))
sb.countplot(x='age',hue='Dosage', data=df, palette="Blues")
plt.title('Dosage by Age', fontsize = 20)
plt.xticks(rotation = 90)
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend(('1','2', '3'),title='Dosage')
plt.show()

# %%
fig = px.bar(df, x="age", y=["Mem_Score_After","Mem_Score_Before"], title="Mem Score Before and Mem Score After over Age",
             color_discrete_sequence=["#8292ba","#b3bdd5"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ax = sns.barplot(x='Drug',y='Mem_Score_Before', data=df,
                 palette="vlag").set(title='Mem Score Before over Drug')

# %%
ax = sns.barplot(x='Drug',y='Mem_Score_Before', hue="Dosage", data=df,
                 palette="vlag").set(title='Mem Score Before over Drug by Dosage')

# %%
ax = sns.barplot(x='Drug',y='Mem_Score_Before', hue="Happy_Sad_group", data=df,
                 palette="Blues_d").set(title='Mem Score Before over Drug by Happy and Sad group')

# %%
ax = sns.barplot(x='Drug',y='Mem_Score_After', data=df,
                 palette="vlag").set(title='Mem Score After over Drug')

# %%
ax = sns.barplot(x='Drug',y='Mem_Score_After', hue="Dosage", data=df,
                 palette="vlag").set(title='Mem Score After over Drug and Dosage')

# %%
ax = sns.barplot(x='Drug',y='Mem_Score_After', hue="Happy_Sad_group", data=df,
                 palette="Blues_d").set(title='Mem Score After over Drug for Happy and Sad group')

# %%
sns.scatterplot(data=df, x="Drug", y="Diff", hue="Dosage").set(title='Difference over Happy vs Sad gruop by Drug')
# Out:
# [Text(0.5, 1.0, 'Difference over Happy vs Sad gruop by Drug')]

# %%
sns.scatterplot(data=df, x="age", y="Mem_Score_After", hue="Dosage").set(title='Mem score After over Age by Dosage')
# Out:
# [Text(0.5, 1.0, 'Mem score After over Age by Dosage')]

# %%
sns.scatterplot(data=df, x="age", y="Mem_Score_Before", hue="Dosage").set(title='Mem score Before over Age by Dosage')
# Out:
# [Text(0.5, 1.0, 'Mem score Before over Age by Dosage')]

# %%
sns.scatterplot(data=df, x="age", y="Diff", hue="Dosage").set(title='Difference over Age by Dosage')
# Out:
# [Text(0.5, 1.0, 'Difference over Age by Dosage')]

# %%
sns.scatterplot(data=df, x="age", y="Diff", hue="Drug").set(title='Difference over Age by Drug')
# Out:
# [Text(0.5, 1.0, 'Mem score Before over Age by Drug')]

# %%
sns.scatterplot(data=df, x="Happy_Sad_group", y="Diff", hue="Dosage").set(title='Difference over Happy vs Sad gruop by Dosage')
# Out:
# [Text(0.5, 1.0, 'Difference over Happy vs Sad gruop by Dosage')]

# %%
sns.scatterplot(data=df, x="Happy_Sad_group", y="Diff", hue="Drug").set(title='Difference over Happy vs Sad gruop by Drug')
# Out:
# [Text(0.5, 1.0, 'Difference over Happy vs Sad gruop by Drug')]

# %%
sns.scatterplot(data=df, x="Dosage", y="Diff", hue="Drug").set(title='Difference over Happy vs Sad gruop by Drug')
# Out:
# [Text(0.5, 1.0, 'Difference over Happy vs Sad gruop by Drug')]

# %%
fig = px.bar(df.sort_values('Diff', ascending=False)[:20][::-1], 
             x='Diff', y='name',  hover_data=['Diff', 'name'], color='Dosage',
             
             title='Patient with Higest Difference by Dosage', text='Diff', orientation='h',color_discrete_sequence=["#53b0e6"])

             
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df.sort_values('Diff', ascending=True)[:20][::-1], 
             x='Diff', y='name',  hover_data=['Diff', 'name'], color='Dosage',
             
             title='Patient with lowest Difference by Dosage', text='Diff', orientation='h',color_discrete_sequence=["#53b0e6"])

             
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df.sort_values('Diff', ascending=True)[:20][::-1], 
             x='Diff', y='name',  hover_data=['Drug','Diff'], color='Drug',
          
             title='Patient with Higest Difference by Drug', text='Diff', orientation='h',color_discrete_sequence=["#53b0e6","#46039f","#7201a8"])


             
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df.sort_values('Diff', ascending=True)[:20][::-1], 
             x='Diff', y='name',hover_data=['Dosage', 'Mem_Score_After'], color='Dosage',
             title='Patient with Higest Mem Score After by Dosage', text='Mem_Score_After', orientation='h')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df.sort_values('Diff', ascending=True)[:20][::-1], 
             x='Diff', y='name',hover_data=['Dosage', 'Mem_Score_Before'], color='Dosage',
             title='Patient with Higest Mem Score Before', text='Mem_Score_Before', orientation='h')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df.sort_values('Mem_Score_After', ascending=True)[::-1], 
             x='Mem_Score_After', y=df.index,hover_data=['Dosage', 'Mem_Score_After'], color='Dosage',
             title='Patient by Mem Score After over Dosage', text='Mem_Score_After', orientation='h')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df.sort_values('Mem_Score_After', ascending=True)[::-1], 
             x='Mem_Score_After', y=df.index,hover_data=['Happy_Sad_group', 'Mem_Score_After'], color='Happy_Sad_group',
             title='Patient by Mem Score After over Happy Sad group', text='Mem_Score_After', orientation='h')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df.sort_values('Mem_Score_After', ascending=True)[::-1], 
             x='Mem_Score_After', y=df.index,hover_data=['Drug', 'Mem_Score_After'], color='Drug',
             title='Patient by Mem Score After over Drug', text='Mem_Score_After', orientation='h')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df.sort_values('Diff', ascending=True)[::-1], 
             x='Diff', y=df.index,hover_data=['Dosage', 'Mem_Score_After'], color='Dosage',
             title='Patient by Difference over Dosage', text='Mem_Score_After', orientation='h')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df.sort_values('Diff', ascending=True)[::-1], 
             x='Diff', y=df.index,hover_data=['Happy_Sad_group', 'Diff'], color='Happy_Sad_group',
             title='Patient by Difference over Happy Sad group', text='Mem_Score_After', orientation='h')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df.sort_values('Diff', ascending=True)[::-1], 
             x='Diff', y=df.index,hover_data=['Drug', 'Diff'], color='Drug',
             title='Patient by Difference over Drug', text='Diff', orientation='h')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
